# %%
import yolo_for_cnn as yfc

# %%
from tqdm import tqdm
from glob import glob
import os

# %% [markdown]
# # unzip

# %%
# cctv_without
# %cd cctv_without

# !unzip /home/lab16/cnn/dataset/cctv_without.zip

files = glob('/home/lab16/cnn/Modeling/Yolo/cctv_without/*')
new_image_path='/home/lab16/cnn/dataset/cctv_without_crop/'
print(len(files))
for file in tqdm(files):
    image_path,image_name=os.path.split(file)
    image_path=image_path+'/'
    yfc.crop_image(image_path,image_name,new_image_path)

files= glob('/home/lab16/cnn/dataset/cctv_without_crop/*')
print(len(files))

# %%
# cctv_with
# %cd /home/lab16/cnn/Modeling/Yolo/cctv_with

# !unzip /home/lab16/cnn/dataset/cctv_with.zip

files = glob('/home/lab16/cnn/Modeling/Yolo/cctv_with/*')
new_image_path='/home/lab16/cnn/dataset/cctv_with_crop/'
print(len(files))
for file in tqdm(files):
    image_path,image_name=os.path.split(file)
    image_path=image_path+'/'
    yfc.crop_image(image_path,image_name,new_image_path)

files= glob('/home/lab16/cnn/dataset/cctv_with_crop/*')
print(len(files))

# %%
files= glob('/home/lab16/cnn/dataset/cctv_with_crop/*')
print(len(files))

# %%
#!unzip /home/lab16/cnn/dataset/without_leash_valid_ver4.zip

# %% [markdown]
# # Train

# %% [markdown]
# ## with-leash

# %%
file_path='/home/lab16/cnn/dataset/with_leash_train_ver4/'
files = glob(file_path+'*')
print(len(files))
new_image_path='/home/lab16/cnn/dataset/with_leash_train_ver4-crop/'

# %%
for file in tqdm(files):
    image_path,image_name=os.path.split(file)
    image_path=image_path+'/'
    yfc.crop_image(image_path,image_name,new_image_path)

# %% [markdown]
# ## without-leash

# %%
file_path='/home/lab16/cnn/dataset/without_leash_train_ver4/'
files = glob(file_path+'*')
print(len(files))
new_image_path='/home/lab16/cnn/dataset/without_leash_train_ver4-crop/'

# %%
for file in tqdm(files):
    image_path,image_name=os.path.split(file)
    image_path=image_path+'/'
    yfc.crop_image(image_path,image_name,new_image_path)

# %% [markdown]
# # Valid

# %% [markdown]
# ## with-leash

# %%
file_path='/home/lab16/cnn/dataset/with_leash_valid_ver4/'
files = glob(file_path+'*')

new_image_path='/home/lab16/cnn/dataset/with_leash_valid_ver4-crop/'

# %%
for file in tqdm(files):
    image_path,image_name=os.path.split(file)
    image_path=image_path+'/'
    yfc.crop_image(image_path,image_name,new_image_path)

# %% [markdown]
# ## without-leash

# %%
file_path='/home/lab16/cnn/dataset/without_leash_valid_ver4/'
files = glob(file_path+'*')

new_image_path='/home/lab16/cnn/dataset/without_leash_valid_ver4-crop/'

# %%
for file in tqdm(files):
    image_path,image_name=os.path.split(file)
    image_path=image_path+'/'
    yfc.crop_image(image_path,image_name,new_image_path)
