# %%
import gradcam as gcm
from keras.models import load_model

model=load_model('../project/0210_ResNet101V2_model_crop')
gcm.show_GradCAM(img_path='crop_without_64.jpg',img_size=(224,224),model=model,last_conv_layer_name = 'conv5_block3_3_conv')

# %%
model=load_model('../project/0210_ResNet101V2_model_crop')
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
gcm.show_GradCAM(img_path='crop_without_64.jpg',img_size=(224,224),model=model,last_conv_layer_name = 'conv5_block3_3_conv')
# Out:
# (1, 224, 224, 3)
# 1/1 [==============================] - 1s 1s/step
# with vs without
# [[-0.8237122   0.56848186]]
# 0

# %%
model.pred
