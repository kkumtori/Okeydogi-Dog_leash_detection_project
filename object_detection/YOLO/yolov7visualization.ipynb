# %% [markdown]
# # 데이터 셋 불러오기

# %%
#! curl -L 'https://app.roboflow.com/ds/##################' > roboflow.zip ; unzip roboflow.zip

# %% [markdown]
# # Yolov5 or 7 Git Clone

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1127, done.
# remote: Total 1127 (delta 0), reused 0 (delta 0), pack-reused 1127
# Receiving objects: 100% (1127/1127), 69.93 MiB | 28.54 MiB/s, done.
# Resolving deltas: 100% (522/522), done.

# %%
cd yolov7
# Out:
# /content/yolov7

# %%
pip install -r requirements.txt

# %% [markdown]
# # 검증하기

# %%
# !python test.py --data '../data.yaml' --img 640 --batch 32 --conf 0.5 --iou 0.65 --device 0 --weights '/content/drive/MyDrive/SH/project/0210_yolov7_epochs_42.pt' --verbose
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.5, data='../data.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', v5_metric=False, verbose=True, weights=['/content/drive/MyDrive/SH/project/0210_yolov7_epochs_42.pt'])
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36907898 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...
