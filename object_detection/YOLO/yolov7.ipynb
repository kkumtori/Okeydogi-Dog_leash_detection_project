# %%
cd 프로젝트/v7/yolov7
# Out:
# [Errno 2] No such file or directory: '프로젝트/v7/yolov7'
# /home/lab15/프로젝트/v7

# %% [markdown]
# # 데이터 셋 불러오기

# %%
#! curl -L 'https://app.roboflow.com/ds/#################' > roboflow.zip ; unzip roboflow.zip

# %% [markdown]
# # Yolov7 Git Clone

# %%
#!git clone https://github.com/WongKinYiu/yolov7
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1127, done.
# remote: Total 1127 (delta 0), reused 0 (delta 0), pack-reused 1127
# Receiving objects: 100% (1127/1127), 69.93 MiB | 24.28 MiB/s, done.
# Resolving deltas: 100% (522/522), done.

# %%
#pip install -r requirements.txt

# %% [markdown]
# # Default 가중치파일 설치

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %% [markdown]
# # 학습
# ## 60epochs을 주었으나 서버 사용시간으로 인해 55epochs을 돌고 중지

# %%
# !python train.py --device 0 --batch-size 16 --data ../data.yaml --cache --img 640 --epochs 60 --cfg ./cfg/training/yolov7.yaml --weights './yolov7.pt' --name yolov7 --hyp data/hyp.scratch.p6.yaml --cfg './cfg/training/yolov7.yaml'
# Out:
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
# Traceback (most recent call last):
#   File "train.py", line 616, in <module>
#     train(hyp, opt, device, tb_writer)
#   File "train.py", line 80, in train
#     assert len(names) == nc, '%g names found for nc=%g dataset in %s' % (len(names), nc, opt.data)  # check
# AssertionError: 27 names found for nc=28 dataset in ../data.yaml

# %% [markdown]
# # 추론

# %%
# !python detect.py --source '/content/drive/MyDrive/dogs.mp4' --weights 'home/lab15/프로젝트/v7/yolov7/runs/train/yolov720/weights/best.pt' --iou 0.6 --conf 0.5 --classes 27
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=[27], conf_thres=0.5, device='', exist_ok=False, img_size=640, iou_thres=0.6, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/drive/MyDrive/dogs.mp4', update=False, view_img=False, weights=['/content/yolov7/runs/train/yolov720/weights/best.pt'])
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.10.0 CUDA:0 (Tesla T4, 14910.375MB)
#
# Traceback (most recent call last):
#   File "detect.py", line 196, in <module>
#     detect()
#   File "detect.py", line 34, in detect
#     model = attempt_load(weights, map_location=device)  # load FP32 model
#   File "/home/lab15/프로젝트/v7/yolov7/models/experimental.py", line 252, in attempt_load
#     ckpt = torch.load(w, map_location=map_location)  # load
#   File "/home/ubuntu/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/torch/serialization.py", line 594, in load
#     with _open_file_like(f, 'rb') as opened_file:
# ...
